# %%
import numpy as np
import time

# %%
size=100000
py_list=list(range(size))
start=time.time()
sq_list=[x**2  for x in py_list]
end=time.time();
print(f" python time={end-start} seconds")
# Out:
#  python time=0.03620147705078125 seconds

# %%
np_arr=np.array(py_list)
start=time.time()
sq_array=np_arr**2
end=time.time()
print(f"numpy takes ={end-start}seconds")
# Out:
# numpy takes =0.001238107681274414seconds

# %%
arr=np.array([1,2,3,4])
print(arr,type(arr),arr.shape)
# Out:
# [1 2 3 4] <class 'numpy.ndarray'> (4,)

# %%
array=np.array([[1,2,3],[7,8,9],[3,5,6]])
print(array)
# Out:
# [[1 2 3]
#  [7 8 9]
#  [3 5 6]]

# %%
arr=np.zeros((2,3))
print(arr)
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]]
